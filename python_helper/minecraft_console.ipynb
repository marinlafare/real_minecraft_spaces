# %%
import os
from pathlib import Path
import ebooklib
from ebooklib import epub

# %%
book = epub.read_epub('block_book/blocks.epub')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 book = epub.read_epub('block_book/blocks.epub')
#
# File ~/anaconda3/envs/minecraft/lib/python3.12/site-packages/ebooklib/epub.py:1634, in read_epub(name, options)
#    1620 """
#    1621 Creates new instance of EpubBook with the content defined in the input file.
#    1622
#    (...)   1630   Instance of EpubBook.
#    1631 """
#    1632 reader = EpubReader(name, options)
# -> 1634 book = reader.load()
#    1635 reader.process()
#    1637 return book
#
# File ~/anaconda3/envs/minecraft/lib/python3.12/site-packages/ebooklib/epub.py:1334, in EpubReader.load(self)
#    1333 def load(self):
# -> 1334     self._load()
#    1336     return self.book
#
# File ~/anaconda3/envs/minecraft/lib/python3.12/site-packages/ebooklib/epub.py:1581, in EpubReader._load(self)
#    1579 def _load(self):
#    1580     try:
# ...

# %%
book

# %%
a = 0
for doc in book.get_items_of_type(ebooklib.ITEM_DOCUMENT):
    print(doc)
    a+=1
print(a)

# %%
original_page = 10
current_page = original_page + 3

# %%
titles = []
spans = []
for page in book.get_items_of_type(ebooklib.ITEM_DOCUMENT):
    try:
        soup = BeautifulSoup(page.__dict__['content'])
        title = soup.find('title')
        span = soud.find('span')
        titles.append(title.text)
        spans.append(span.text)
    except:
        pass
#pages = [BeautifulSoup(one_page) for one_page in list(book.get_items_of_type(ebooklib.ITEM_DOCUMENT))[current_page].__dict__['content']]
# Out:
# /tmp/ipykernel_18425/1316787793.py:5: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(page.__dict__['content'])

# %%
titles_set = list(set(titles))
spans_set = list(set(spans))

# %%
e = list(book.get_items_of_type(ebooklib.ITEM_DOCUMENT))

# %%
grass = "Grass"

# %%
useless = ['Cover',
             'Continued',
             'Copyright',
             'Title Page',
             'Contents',
             'Using This Book',
             'Blocks, So Many Blocks ...',
              'Wool',
             'Torch',
             'Soul Torch',
             'Lantern',
              'Minecraft: Blockopedia','Index','Banners',
             'Flower Pot',
             'Turtle Egg',
             'Dragon Egg','Signs',
             'Lightning Rod',
             'Redstone Dust',
             'Redstone Torch',
             'Buttons',
             'Lever',
                      'Anvil',
             'Beds',
             'Bell','Jigsaw','Redstone Lamp',
             'Rail',
             'Powered Rail',
             'Carpets']
titles = []
for item in e:
    try:
        soup = BeautifulSoup(item.__dict__['content'])
        title_text = soup.find('title').text
        if ", Minecraft: Blockopedia" in title_text:
            title = title_text.replace(", Minecraft: Blockopedia","")
        else:
            continue
        if 'Section' in title:
            continue
        if title in useless:
            continue
        else:
            titles.append(title)
    except:
        pass
# Out:
# /tmp/ipykernel_18425/4105289274.py:30: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(item.__dict__['content'])

# %%
len(titles)
# Out:
# 235

# %%
titles
# Out:
# ['Bedrock',
#  'Air',
#  'Water',
#  'Grass Block',
#  'Podzol',
#  'Mycelium',
#  'Dirt',
#  'Farmland',
#  'Dirt Path',
#  'Gravel',
#  'Sand',
#  'Clay',
#  'Cobbleston',
#  'Stone',
#  'Diorite',
#  'Andesite',
#  'Granite',
#  'Deepslate',
#  'Cobbled Deepslate',
#  'Smooth Basalt',
#  'Tuff',
#  'Calcite',
#  'Budding Amethyst',
#  'Block of Amethyst',
#  'Dripstone Block',
#  'Sandstone',
#  'Red Sandstone',
#  'Infested Blocks',
#  'Prismarine',
#  'Obsidian',
#  'Lava',
#  'Magma Block',
#  'Fire',
#  'Ice',
#  'Packed Ice',
#  'Blue Ice',
#  'Frosted Ice',
#  'Snow Block',
#  'Powder Snow',
#  'Nether Portal Block',
#  'End Portal Frame',
#  'End Portal Block',
#  'End Gateway',
#  'Nylium',
#  'Netherrack',
#  'Shroomlight',
#  'Soul Sand',
#  'Soul Soil',
#  'Blackstone',
#  'Polished Blackstone Bricks',
#  'Gilded Blackstone',
#  'Basalt',
#  'End Stone',
#  'End Stone Brick Slab',
#  'Soul Fire',
#  'Bone Block',
#  'Pointed Dripstone',
#  'Cobweb',
#  'Sponge',
# ...

# %%
print(soups[30].prettify())
# Out:
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml" xmlns:epub="http://www.idpf.org/2007/ops">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=711,height=711" name="viewport"/>
#   <title>
#    Continued, Minecraft: Blockopedia
#   </title>
#   <link href="../css/9780593355916_style.css" rel="stylesheet" type="text/css"/>
#   <meta content="urn:uuid:539e6720-e535-4f2a-99d5-ff830e3faa49" name="Adept.expected.resource"/>
#  </head>
#  <body id="x9780593355916_v2-31" lang="en-GB" style="width:711px;height:711px" xml:lang="en-GB">
#   <div id="spread_31-div-1">
#    <img alt="pageMap_29" class="_idGenObjectAttribute-1 _idGenObjectAttribute-2" src="../images/page_29.jpg"/>
#   </div>
#   <div class="General-Text-Boxes_-Found--Tbox" id="spread_31-div-2">
#    <div id="spread_31-div-17">
#     <p class="Heading_Heading-3-Stat-Found-Box ParaOverride-1">
#      <span class="CharOverride-17" id="spread_31-span-1">
#       FOUND:
#      </span>
#     </p>
# ...

# %%
e[0]

# %%
Grass

# %%
for i in titles_set:
    print(i.replace(", Minecraft: Blockopedia",""))

# %%
soup = BeautifulSoup(one_page)

# %%
print(soup.prettify())
# Out:
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml" xmlns:epub="http://www.idpf.org/2007/ops">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=711,height=711" name="viewport"/>
#   <title>
#    Bedrock, Minecraft: Blockopedia
#   </title>
#   <link href="../css/9780593355916_style.css" rel="stylesheet" type="text/css"/>
#   <meta content="urn:uuid:539e6720-e535-4f2a-99d5-ff830e3faa49" name="Adept.expected.resource"/>
#  </head>
#  <body id="x9780593355916_v2-14" lang="en-GB" style="width:711px;height:711px" xml:lang="en-GB">
#   <div class="Basic-Text-Frame" id="spread_14-div-1">
#    <div id="spread_14-div-3">
#     <p class="xnav_doc_entry ParaOverride-1" id="_idParaDest-8">
#      <span class="CharOverride-1" id="spread_14-span-1">
#       Bedrock
#      </span>
#     </p>
#    </div>
#   </div>
#   <div id="spread_14-div-2">
#    <img alt="pageMap_12" class="_idGenObjectAttribute-1 _idGenObjectAttribute-2" src="../images/page_12.jpg"/>
#   </div>
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("<p>Some<b>bad<i>HTML")
# Out:
# <html>
#  <body>
#   <p>
#    Some
#    <b>
#     bad
#     <i>
#      HTML
#     </i>
#    </b>
#   </p>
#  </body>
# </html>

# %%
def extract_images(epub_file_path, output_directory):
    book = epub.read_epub(epub_file_path)
    Path(output_directory).mkdir(parents=True, exist_ok=True)
    for item in book.get_items():
        if item.media_type.startswith('image/'):
            image_name = item.file_name
            image_path = Path(output_directory) / image_name
            with open(image_path, 'wb') as f:
                f.write(item.get_content())
    return 'DONE'

# %%
epub_file_path = 'block_book/blocks.epub'
output_directory = 'extracted_images'
# extract_images(epub_file_path, output_directory)

# %%
path_images = os.listdir('extracted_images/images')

# %%
len(path_images)
# Out:
# 339

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11x.pt")
# Out:
# /home/jon/anaconda3/envs/minecraft/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
test = ['extracted_images/images/'+x for x in path_images[100:130]]

# %%
results = model(test)  # return a list of Results objects

# %%
results[0]

# %%
for result in results[:10]:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    #result.save(filename="result.jpg")  # save to disk

# %%
# Load a model
model = YOLO("yolo11n.pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model(["image1.jpg", "image2.jpg"])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk

# %%
# Load a pretrained YOLO11n model

# Train the model on the COCO8 dataset for 100 epochs
train_results = model.train(
    data="coco8.yaml",  # Path to dataset configuration file
    epochs=100,  # Number of training epochs
    imgsz=640,  # Image size for training
    device="cpu",  # Device to run on (e.g., 'cpu', 0, [0,1,2,3])
)

# Evaluate the model's performance on the validation set
metrics = model.val()

# Perform object detection on an image
results = model("path/to/image.jpg")  # Predict on an image
results[0].show()  # Display results

# Export the model to ONNX format for deployment
path = model.export(format="onnx")  # Returns the path to the exported model
